# %% [markdown]
# shell 정렬은 insertion 정렬을 확장한 개념으로 전체 데이터를 반으로 나눠 블록으로 나누고 정렬을 한 후 계속 반으로 나눠 블록을 만들어 정렬하는 방식이다.

# %%
from IPython.display import Image
Image('./shellSort_1.png', width = '500')

# %%
from IPython.display import Image
Image('./shellSort_2.png', width = '500')

# %%
from IPython.display import Image
Image('./shellSort_3.png', width = '500')

# %%
from IPython.display import Image
Image('./shellSort_4.png', width = '500')

# %%
data = [19, 2, 31, 45, 30, 11, 121, 27]
# print(len(data))
mid = len(data) // 2 # 정렬할 데이터의 중간 위치를 계산한다. => 블록의 크기

# 정렬할 데이터의 개수에 따라서 회전수가 달라지므로 정렬할 데이터의 중간 위치가 0보다 큰 동안 반복하며 정렬한다.
while mid > 0:
    for i in range(mid, len(data)):
        key = data[i]
        index = i
        while index >= mid and data[index - mid] > key:
            data[index] = data[index - mid]
            index -= mid
        # ===== while 끝
        data[index] = key
    # ===== for i 끝 => 회전 종료
    print(data)
    mid //= 2
# ===== while mid > 0 끝 => 정렬 종료
# Out:
# [19, 2, 31, 27, 30, 11, 121, 45]
# [19, 2, 30, 11, 31, 27, 121, 45]
# [2, 11, 19, 27, 30, 31, 45, 121]
