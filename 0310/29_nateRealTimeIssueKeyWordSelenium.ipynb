# %%
# selenium을 사용하기 위해 selenium을 설치하고 import 한다.
# !pip install selenium

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
from datetime import datetime as dt
from selenium import webdriver

# %%
# selenium을 사용해 가상 크롬을 실행한다. => 사용중인 크롬 버전과 같은 버전의 크롬 드라이버를 다운받는다.
driver = webdriver.Chrome('./chromedriver.exe')
# get() 메소드로 가상 크롬에 크롤링 할 타겟 사이트를 띄운다.
driver.get('https://www.nate.com/')
# 크롤링할 html 정보를 읽어온다.
html = driver.page_source
# print(html)
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <html class="ua-win10 ua-chrome" lang="ko"><head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="//www.nate.com/" name="msapplication-starturl"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="" name="nate:title"/>
# <meta content="네이트 이슈UP" name="nate:description"/>
# <meta content="네이트 홈" name="nate:site_name"/>
# <meta content="https://www.nate.com/" name="nate:url"/>
# <meta content="" name="nate:image"/>
# <meta content="새로워진 nate에서 당신의 오늘을 만나보세요" name="description"/>
# <meta content="한눈에 보는 오늘 : 네이트" property="og:title"/>
# <meta content="https://www.nate.com/" property="og:url"/>
# <meta content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" property="og:image"/>
# <meta content="새로워진 nate에서 당신의 오늘을 만나보세요" property="og:description"/>
# <title>한눈에 보는 오늘 : 네이트</title>
# <link href="/css/common.min.css?v=202103041339_01" rel="stylesheet" type="text/css"/>
# <link href="//main.nateimg.co.kr/img/v7/favicon_32.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="/js/common/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	var isSvc = true; var isInfoAjax = true;
# 	var make = 't';
# 	var isMakeLogin = '';
# 	var host = 'www.nate.com';
#
# 	var isNateLogin = (isMakeLogin == "Y") ? true : false;
# 	var myId = "";
# 	var iSvcSeq  ='2';
# 	var iSvcSeqB ='2';
# 	var iSvcSeqC ='2';
# 	var currentWeatherIndex = [0,11,8];
# 	var iSvcSeqW = iSvcSeqB;
# 	var isCommsbarOpen = ('N' == 'Y') ? true : false;
# 	var loginType = '';
# 	var isiPad = (navigator.userAgent.toUpperCase().indexOf("IPAD") !== -1);
# 	var isGalaxyTab = (navigator.userAgent.toUpperCase().indexOf("SHW-M180") !== -1); // GT-P1000
# 	var isGalaxyTab10 = (navigator.userAgent.toUpperCase().indexOf("SHW-M380") !== -1);
# 	var isTablet = (isiPad == true || isGalaxyTab == true || isGalaxyTab10 == true);
# 	if (isTablet)
# 	{
# 	    document.write('<link rel="apple-touch-icon-precomposed" href="//main.nateimg.co.kr/img/nate_144.png" />');
# 	}
# 	var loginBoxName 	= "아이디 or @이하 모두 입력";
# 	var hostInfo 	 	= (host.length > 0) ? '//' + host : '';
#
# 	var verContJs		= '202001141024';
# 	var verIssue01 		= '202103102102';
# 	var verIssue02 		= '202103102102';
# 	var verIssue03 		= '202103102102';
# 	var verIssue04 		= '202103102102';
# 	var verIssue05 		= '202103102102';
# 	var verIssue06 		= '202103102102';
# 	var verIssue07 		= '202103102102';
#
# 	var verNateTV		= '202103102113';
# 	var verIssueKeyword	= '202103102115';
# 	var verRanking03	= '202103102117';
# 	var verRanking04	= '202103051256';
# 	var verRanking05	= '201907240902';
# 	var verRanking06	= '202103102103';
# 	var verNateQ01		= '202103102058';
#
# 	var verCntsU01 		= '202011180210';
# 	var verCntsU02 		= '201907240831';
# 	var verCntsU03 		= '202103102103';
# 	var verGnbRoll		= '202103102102';
# 	var verNewsBox 		= '202103102117';
# 	var verShopRecomm	= '202103102110';
# 	var verNateQ02		= '202103102104';
#
# 	var verPannChoice	= '202103102111';
# 	var verPannToday	= '202103102111';
# 	var verPannRanking	= '202103102111';
# 	var verPannReply	= '202103102112';
# 	var verTodayKeyword = '202103102118';
# 	var verBizSearch 	= '202101211319';
# 	var verPann01 		= '201907240835';
# 	var verPann02 		= '201907240835';
#
# 	var shoppingInspection 		= 'N';
# 	var isEmergencyShoppingTab 	= 'N';
# 	var isAutoRefresh 			= true;
# 	var isChangeTab 			= false;
# 	var nateAwardsStat			= '';
# 	var isViewKeywordRank		= 'N';
#
# 	//]]>
# 	</script>
# <script src="/js/common/nate_general_v20170627.js?v=202101251103_14" type="text/javascript"></script>
# <script src="/js/common/nate_logout_v20170627.js?v=202001141024_01" type="text/javascript"></script>
# <script type="text/javascript">
# 		 //<![CDATA[
# 			var bLogout = false;
# 	    	if (isLogout()) { fillLogout(); }
# 		 //]]>
# 		</script>
# <link href="/css/nateAd/NateAdVideo.css?202002211327" rel="stylesheet" type="text/css"/><script src="/js/common/NateAdVideo.js?202002211327"></script><script src="//www.nate.com/js/data/bizhotkwd_rel.js?v=202101211319"></script><script charset="euc-kr" src="//www.nate.com/main/srv/news/data/news_data_common_v20200521.js?v=1202103102117" type="text/javascript"></script><script charset="UTF-8" src="//cyad1.nate.com/js.kti/nate/main3@m_Top1" type="text/javascript"></script><script charset="UTF-8" src="//cyad1.nate.com/js.kti/nate/www.nate.com@main2_Right1" type="text/javascript"></script><script charset="UTF-8" src="//cyad1.nate.com/js.kti/nate/main@blank_Right3" type="text/javascript"></script><script charset="euc-kr" src="//cyad1.nate.com/js.kti/nate/main@td_cont_0" type="text/javascript"></script><script charset="euc-kr" src="//cyad1.nate.com/js.kti/native/main@shop_imp_x05" type="text/javascript"></script></head>
# <body>
# <script type="text/javascript">
# 	 //<![CDATA[
# 		pageEnd2('st');
# 	 //]]>
# 	</script>
# <div id="mainContainer">
# <div class="area_access">
# <h2>네이트 메인페이지 내용 바로가기 링크</h2>
# <ul>
# <li><a href="#search"><strong>통합검색 바로가기</strong></a></li>
# <li><a href="#UI"><strong>로그인영역 바로가기</strong></a></li>
# <li><a href="#news_area"><strong>본문영역 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="container">
# <div id="header">
# <div class="area_bi" id="NateBi" role="banner">
# <h1 class="bi" title="네이트"><a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a></h1>
# </div>
# <div class="area_ignb" id="divignb">
# <h2>독립GNB</h2>
# <h3>편리한 네이트</h3>
# <ul>
# <li class="set_home" id="setHomeBtn"><a href="https://erms.nate.com/faq/exSelfFAQA.jsp?PageNo=1&amp;nodeId=NODE0000001315&amp;parentNodeId=NODE0000001207&amp;grandParentNodeId=&amp;nodeDepth=4&amp;checkFaq=0&amp;faqId=FAQS0000012878&amp;index=7" onmousedown="nc('NBI47');">네이트를 시작페이지로</a></li><li><a href="https://search.daum.net/nate?thr=sbma&amp;w=tot&amp;q=%EB%84%A4%EC%9D%B4%ED%8A%B8%EC%95%B1" onmousedown="nc('NBI04');">네이트앱</a></li>
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NBI05');">네이트온</a></li>
# <li><a href="http://www.cymera.com/main/ko" onmousedown="nc('NBI07');">싸이메라</a></li>
# </ul>
# </div>
# <div class="area_search" role="search">
# <h2>통합검색</h2>
# <form accept-charset="utf-8" action="https://search.daum.net/nate" id="search" name="search" onsubmit="return checkSearchForm()">
# <input id="thr" name="thr" type="hidden" value="sbma"/>
# <input id="w" name="w" type="hidden" value="tot"/>
# <fieldset>
# <legend>통합검색 입력</legend>
# <div class="home" id="acWrap" onmouseover="ac_LoadByNateMain();">
# <input autocomplete="off" class="type_text" id="q" name="q" onkeydown="return checkSearchQEnter(event)" style="ime-mode:active" type="text" value=""/>
# <input class="type_btn" id="acBtn" title="검색" type="submit"/>
# <div id="acDiv" style="display:none;">
# <iframe frameborder="0" id="acIfrm" marginheight="0" marginwidth="0" name="acIfrm" scrolling="no" src="about:blank" title="자동완성영역"></iframe>
# </div>
# </div>
# </fieldset>
# </form>
# <input id="premiumText" name="premiumText" title="" type="hidden" value=""/>
# <input id="premiumLink" name="premiumLink" title="" type="hidden" value=""/>
# <input id="statCode" name="statCode" title="" type="hidden" value=""/>
# <div class="search_keyword">
# <dl>
# <dd>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%9C%A0%EB%85%B8%EC%9C%A4%ED%98%B8+%EC%9E%85%EA%B1%B4%EB%8F%BC" id="onclick_semantic01" onmousedown="setNcCode('NSC11|NSC21|NSC31',iSvcSeq-1);">유노윤호 입건</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%97%90%EC%96%B4%EC%83%A4%EC%9B%8C%EA%B8%B0" id="onclick_semantic02" onmousedown="setNcCode('NSC12|NSC22|NSC32',iSvcSeq-1);">에어샤워기</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%9A%B4%EC%A0%84%EC%9E%90%EB%B3%B4%ED%97%98" id="onclick_semantic03" onmousedown="setNcCode('NSC13|NSC23|NSC33',iSvcSeq-1);">운전자보험가입팁</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%A1%B0%EB%B3%91%EA%B7%9C+%EB%B0%98%EB%B0%95" id="onclick_semantic04" onmousedown="setNcCode('NSC14|NSC24|NSC34',iSvcSeq-1);">조병규 반박</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%ED%99%A9%EA%B5%90%EC%95%88+%EB%B3%B5%EA%B7%80+%EC%84%A0%EC%96%B8%ED%95%B4" id="onclick_semantic05" onmousedown="setNcCode('NSC15|NSC25|NSC35',iSvcSeq-1);">황교안 복귀</a>
# </dd>
# </dl>
# </div>
# </div>
# <div class="area_gnb" id="divGnb" role="navigation">
# <h2>GNB</h2>
# <ul>
# <li class="mail"><a href="http://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>
# <li class="news"><a href="//news.nate.com/" onmousedown="nc('NEV31');">뉴스</a></li>
# <li class="pann"><a href="https://pann.nate.com/" onmousedown="nc('NGB02');">판</a></li>
# <li class="tv"><a href="https://tv.nate.com/" onmousedown="nc('NGB43');">TV</a></li>
# <li class="comics"><a href="https://comics.nate.com/" onmousedown="nc('NGB39');">만화</a></li>
# <li class="fortune"><a href="https://fortune.nate.com/home/main.nate" onmousedown="nc('NGB05');">운세</a></li>
# <li class="game"><a href="http://game.nate.com/" onmousedown="nc('NGB06');">게임</a></li>
# <li class="shopping"><a href="//shopping.nate.com/" onmousedown="nc('NGB17');">쇼핑</a></li>
# <li class="car"><a href="https://auto.nate.com/" onmousedown="nc('NGB03');">자동차</a></li>
# <li class="stock"><a href="http://stock.nate.com/" onmousedown="nc('NGB41');">증권</a></li>
# <li class="estate"><a href="https://estate.nate.com/" onmousedown="nc('NGB10');">부동산</a></li>
# <li class="teamroom"><a href="https://nateonweb.nate.com/teamroom/" onmousedown="nc('NGB42');" title="함께하는 일이 쉬워진다">팀룸</a></li>
# <li class="type_tactic" id="moreServices">
# <ul class="type_alone">
# <li>
# <a href="#" title=" 팬톡"><img alt=" 팬톡" height="28" src="//main.nateimg.co.kr/img/cms/content_pool/2020/02/1582694078658.png" width="140"/></a></li>
# </ul>
# </li>
# <li class="more">
# <a href="javascript:;" id="aGnbMore" onmousedown="nc('NGB31');" title="전체 서비스 더보기">더보기</a>
# <div class="list_svc" style="display:none">
# <ul class="row_first">
# <li><a href="//news.nate.com" onmousedown="nc('NSD30');"><strong>뉴스</strong></a></li>
# <li><a href="//news.nate.com/Weather" onmousedown="nc('NSD45');">날씨</a></li>
# <li><a href="//sports.news.nate.com/" onmousedown="nc('NSD74');">스포츠</a></li>
# <li><a href="//news.nate.com/ent/index" onmousedown="nc('NSD75');">연예</a></li>
# <li><a href="//news.nate.com/ent/idol24" onmousedown="nc('NSD02');">아이돌24</a></li>
# <li><a href="//news.nate.com/rank/interest" onmousedown="nc('NSD01');">랭킹뉴스</a></li>
# </ul>
# <ul class="row_second">
# <li><a href="https://pann.nate.com/" onmousedown="nc('NSD68');"><strong>판</strong></a></li>
# <li><a href="https://pann.nate.com/talk" onmousedown="nc('NSD06');">톡톡</a></li>
# <li><a href="https://pann.nate.com/talk/imageTheme/index" onmousedown="nc('NSD08');">판포토</a></li>
# <li><a href="https://pann.nate.com/fantalk" onmousedown="nc('NSD76');">팬톡</a></li>
# </ul>
# <ul class="row_third">
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NSD37');">네이트온</a></li>
# <li><a href="//cash.nate.com/center/cashMain.sc" onmousedown="nc('NSD38');">네이트캐쉬</a></li>
# <li><a href="https://sms.nate.com/" onmousedown="nc('NSD35');">문자메시지</a></li>
# <li><a href="https://estate.nate.com/" onmousedown="nc('NSD48');">부동산</a></li>
# <li><a href="http://mail.nate.com/pims/" onmousedown="nc('NSD34');">주소록</a></li>
# <li><a href="http://stock.nate.com/" onmousedown="nc('NSD32');">증권</a></li>
# </ul>
# <ul class="row_fourth">
# <li><a href="//mobile.nate.com/" onmousedown="nc('NSD41');">컬러링</a></li>
# <li><a href="//editor.nate.com/" onmousedown="nc('NSD42');">이슈UP추천</a></li>
# </ul>
# <span><a href="https://www.nate.com/sitemap/index.html" onmousedown="nc('NSD91');">서비스 전체보기</a></span>
# <button onmousedown="nc('NSD95');" title="더보기 닫기" type="button" value="더보기 닫기">더보기 닫기</button>
# </div>
# </li>
# </ul>
# </div>
# <div class="area_rtkwd type_alone" id="keywordRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">실시간 검색어</a></h3>
# </div>
# <div class="area_biz type_alone" id="bizRank"><h3 class="type_biz">Biz. 인기 검색어</h3><div class="kwd_list type_biz" id="bizKwdList"><ol><li class="rank01" style="position: absolute; top: 0px;"><p><span class="num">1</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%EB%85%B8%EC%B6%9C%EC%BD%98%ED%81%AC%EB%A6%AC%ED%8A%B8" onclick="$COMMON.STAT('biz',0);">노출콘크리트</a></p></li><li class="rank02" style="position: absolute; top: 28px;"><p><span class="num">2</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%EC%9E%AC%EC%88%98%EA%B8%B0%EC%88%99%ED%95%99%EC%9B%90" onclick="$COMMON.STAT('biz',1);">재수기숙학원</a></p></li><li class="rank03" style="position: absolute; top: 56px;"><p><span class="num">3</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%ED%99%80%EC%9D%B8%EC%9B%90%ED%8C%A8" onclick="$COMMON.STAT('biz',2);">최고의 홀인원기념</a></p></li><li class="rank04" style="position: absolute; top: 84px;"><p><span class="num">4</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%EC%9A%94%EC%96%91%EC%9B%90%EB%A7%A4%EB%A7%A4" onclick="$COMMON.STAT('biz',3);">요양원매매</a></p></li><li class="rank05" style="position: absolute; top: 112px;"><p><span class="num">5</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%EB%B9%84%EC%83%81%EC%A3%BC%EC%82%AC%EB%AC%B4%EC%8B%A4" onclick="$COMMON.STAT('biz',4);">1인 오피스</a></p></li><li class="rank06" style="position: absolute; top: 140px;"><p><span class="num">6</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%ED%94%84%EB%A0%8C%EC%B0%A8%EC%9D%B4%EC%A6%88%EC%B0%BD%EC%97%85" onclick="$COMMON.STAT('biz',5);">프렌차이즈창업</a></p></li><li class="rank07" style="position: absolute; top: 168px;"><p><span class="num">7</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%EC%BD%94%EC%9D%B8%EB%B9%A8%EB%9E%98%EB%B0%A9%EC%B0%BD%EC%97%85" onclick="$COMMON.STAT('biz',6);">무인빨래방창업</a></p></li><li class="rank08" style="position: absolute; top: 196px;"><p><span class="num">8</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%ED%8C%8C%EB%A0%88%ED%8A%B8%EB%9E%99" onclick="$COMMON.STAT('biz',7);">맞춤 앵글제작</a></p></li><li class="rank09" style="position: absolute; top: 224px;"><p><span class="num">9</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%ED%9A%8C%EA%B3%84%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8" onclick="$COMMON.STAT('biz',8);">쉬운 회계프로그램</a></p></li><li class="rank10" style="position: absolute; top: 252px;"><p><span class="num">10</span><a href="//search.daum.net/nate?w=tot&amp;DA=NBZ&amp;q=%EA%B3%A0%EA%B8%B0%EC%A7%91%EC%B0%BD%EC%97%85" onclick="$COMMON.STAT('biz',9);">고기집창업</a></p></li></ol></div></div>
# <div class="todayBox" id="divTodayKeyworArea" onmouseout="todayKeyword.startTodayKeyword()" onmouseover="todayKeyword.stopTodayKeyword()">
# <div id="divTodayKeyword"><a alt="LH 투기 의혹 전국수사 확대" class="keyword" href="https://news.nate.com/?keyword_dtm=2021-03-10 20:44:00&amp;keyword_sq=54303&amp;index=1" onmousedown="nc('TOD52');">LH 투기 의혹 전국수사 확대</a>
# </div>
# <div class="kwrd_slide">
# <div class="today_tit">
# <a href="https://news.nate.com/" onmousedown="nc('TOD61');">
# <div class="logoimg">
# <div class="circle step1"></div>
# <div class="circle step2"></div>
# </div>
# <span class="svcname">오늘</span>
# </a>
# </div>
# <button class="btn prev" id="Prev" onclick="todayKeyword.viewPreNext('P')" onmousedown="nc('TOD91');" title="이전" type="button"><span>오늘 키워드 이전 내용</span></button>
# <button class="btn next" id="Next" onclick="todayKeyword.viewPreNext('N')" onmousedown="nc('TOD92');" title="다음" type="button"><span>오늘 키워드 다음 내용</span></button>
# </div>
# </div>
# </div>
# <hr/>
# <div id="content">
# <div class="area_auth" id="UI">
# <h2>회원 로그인 영역</h2>
# <script type="text/javascript">
#                     //<![CDATA[
#                         document.write('<script type="text/javascript" src="/common/secure/js/combine/combine_xecure_nate-secure_common.js?v=2014061201"><\/script>');
#                     //]]>
#                     </script><script src="/common/secure/js/combine/combine_xecure_nate-secure_common.js?v=2014061201" type="text/javascript"></script>
# <form action="https://xo.nate.com/LoginAuth.sk" autocomplete="off" id="f_login" method="post" name="f_login" onsubmit="return SubmitCheck();" target="_top">
# <input id="redirect" name="redirect" type="hidden" value="https://www.nate.com/"/>
# <input id="PASSWD_RSA" name="PASSWD_RSA" type="hidden" value=""/>
# <input id="domain" name="domain" type="hidden" value="nate.com"/>
# <input name="cpurl" type="hidden" value="www_ndr.nate.com%2Flogin%2F"/>
# <fieldset>
# <legend>회원 로그인</legend>
# <label class="label_id nHide" for="ID">아이디 or @이하 모두 입력</label>
# <input autocomplete="off" class="input_id" id="ID" name="ID" style="ime-mode:disabled;" title="아이디 or @이하 모두 입력" type="text" value=""/>
# <label class="label_pw nHide" for="PASSDM">비밀번호</label>
# <label class="label_pw nHide" for="PASSDM" id="lb_passdm">비밀번호</label>
# <input class="input_pw" id="PASSDM" maxlength="20" name="PASSDM" readonly="readonly" type="text" value="비밀번호"/>
# <label class="label_pw nHide" for="PASSWD" id="lb_passwd">비밀번호</label>
# <input autocomplete="off" class="input_pw" enc="on" id="PASSWD" maxlength="20" name="PASSWD" onblur="vBlurPassInput();" style="display:none;ime-mode:disabled;" type="password"/>
# <span class="option01"><input class="chk_saveid" id="keeplogin" name="keeplogin" onclick="isKeepLogin('on')" onmousedown="nc('NCM94');" type="checkbox"/> <label class="set_saveid" for="keeplogin" onmousedown="nc('NCM94');">로그인 유지</label> <i class="bar">|</i> <a class="ip" href="javascript:xXecurePop.openWin(3);" onmousedown="nc('NLI15');" title="새창 열림">IP보안 <strong class="two" id="ipLevelText">ON</strong></a></span>
# <input class="icon_login" id="btnLOGIN" name="btnLOGIN" onkeydown="vkeydownSubmit(event);" type="submit" value="로그인"/>
# <span class="option02"><a href="javascript:onclick_Find();">아이디</a> / <a href="javascript:onclick_FindPW();">비밀번호 찾기</a> <i class="bar">|</i> <a href="javascript:onclick_Join();"><strong>회원가입</strong></a> </span>
# <script type="text/javascript">
#                                 //<![CDATA[
#                                     initLogin();
#                                     nateLogin = new NateLogin('f_login', 'btnLOGIN', 'xo.nate.com/servlets/EncLoginServlet', loginBoxName, '비밀번호');
#                                 //]]>
#                                 </script>
# </fieldset>
# </form>
# <div class="overlay_info type_security" id="layerXKDisabled" style="display: none">
# <div class="layer_content"></div>
# </div>
# <div class="overlay_info nHide" id="divNateOn">
# <p>웹 네이트온 로그인은 설치가 필요 없는<br/>가벼운 네이트온이 네이트 로그인 만으로<br/>함께 로그인 되는 편리한 기능입니다.</p>
# <a ;="" href="//nateonweb.nate.com/nateon/download_web.php" onmousedown="nc('NLI75')">웹 네이트온이란?</a>
# <button class="close" onclick="closeWebNateOnInfo()" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# <div class="overlay_info type_saveid nHide">
# <p>개인정보 보호를 위해<br/>개인PC에서만<br/>사용해 주세요. <a href="http://erms.nate.com/faq/exSelfFAQA.jsp?PageNo=1&amp;nodeId=NODE0000001300&amp;parentNodeId=NODE0000000595&amp;grandParentNodeId=&amp;nodeDepth=4&amp;checkFaq=0&amp;faqId=FAQS0000012703&amp;index=6" onmousedown="nc('NLI33');" target="_blank">도움말보기 <i class="icon_arrow_right_red"></i></a></p>
# <button class="icon_x_black" onclick="closeKeepLoginLayer()" onmousedown="nc('NLI32');" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# </div>
# <hr/>
# <h2>컨텐츠 영역</h2>
# <div class="area_news" id="news_area">
# <h3>뉴스</h3>
# <div class="menu" id="newsTabMenu">
# <h4 class="menu01 on" id="newstab1"><a href="javascript:;" onclick="newsBox.clickTabLink('tab1_set1');" title="뉴스탭 열기">뉴스</a></h4>
# <h4 class="menu02" id="newstab2"><a href="javascript:;" onclick="newsBox.clickTabLink('tab2_spo');" title="스포츠탭 열기">스포츠</a></h4>
# <h4 class="menu03" id="newstab3"><a href="javascript:;" onclick="newsBox.clickTabLink('tab3_ent');" title="연예탭 열기">연예</a></h4>
# <h4 class="menu04" id="newstab4" style="display:none;"></h4>
# <h4 class="menu05" id="newstab5"><a href="javascript:;" onclick="newsBox.clickTabLink('tab5_ranking');" title="랭킹뉴스탭 열기">랭킹뉴스</a></h4>
# </div>
# <div class="content type_news" id="newsContType" onfocusin="newsBox.rollingStop();" onfocusout="newsBox.rollingStart();">
# <div class="tabCnt">
# <div class="rankBox" id="div_rank_sisa"></div>
# <div class="rankBox" id="div_rank_spo"></div>
# <div class="rankBox" id="div_rank_ent"></div>
# <ul class="type_thumb type02" id="newsImg_ul_1">
# <li id="newsImg0">
# <a href="//ps.news.nate.com/photo/slideShow?cid=869907&amp;mid=e0102&amp;modit=1615374279" onclick="setTabInfo();ndrclick('MEF06', 'NH_06_01_02-20210310200504');" target="_self"><em class="icon slide">슬라이드</em><span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2021/03/10/1615374251_491.jpg" style="width: 168px; height: 97px;"/></span><span class="txt">나비, 임신 8개월<br/> "여자 인생의 황금기" 행복</span></a>
# </li>
# <li id="newsImg1">
# <a href="//sports.news.nate.com/basketvolley/photo?page=1&amp;cid=869857&amp;fix=869857&amp;modit=1615360157" onclick="setTabInfo();ndrclick('MEF07', 'NH_05_01_01-20210310122156');" target="_self"><em class="icon slide">슬라이드</em><span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2021/03/10/1615346504_991.jpg" style="width: 168px; height: 97px;"/></span><span class="txt">아르헨 여자프로농구 선수<br/>경기 중 모유 수유 화제</span></a>
# </li>
# <li id="newsImg2"><a href="//news.nate.com/view/20210310n42185?modit=1615378628" onclick="setTabInfo();ndrclick('MEF08', 'NH_01_01_04-20210310211720');" target="_self"><em class="icon play">동영상</em><span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2021/03/10/1615378626_265.jpg" style="width: 168px; height: 97px;"/></span><span class="txt">"#가출했어요" 영상 유행<br/>보호 사각지대</span></a></li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_1">
# <li id="newsTxt_li_0"><a href="//news.nate.com/hissue/clstList?mid=n0412&amp;isq=10515&amp;n=818968&amp;modit=1615369190#cid818968" onclick="setTabInfo();ndrclick('MEB39', 'NH_01_02_13-20210310184003');" target="_self"><strong>오후 6시까지 382명, 어제보다 12명↑…내일도 400명대</strong></a></li>
# <li id="newsTxt_li_1"><a href="//news.nate.com/view/20210310n41903?modit=1615377469" onclick="setTabInfo();ndrclick('MEB41', 'NH_01_02_15-20210310205751');" target="_self">옥상서 "살려주세요"…성관계 거부했다고 여성 폭행</a></li>
# <li id="newsTxt_li_2"><a href="//news.nate.com/section?mid=n0500&amp;n=866189&amp;modit=1615377640#cid866189" onclick="setTabInfo();ndrclick('MEB43', 'NH_01_02_17-20210310210057');" target="_self">'램지어 논문 출간' 생고집에…부편집인들, 항의 서한</a></li>
# <li id="newsTxt_li_3"><a href="//sports.news.nate.com/soccer/?modit=1615377481#cid647355" onclick="setTabInfo();ndrclick('MEB45', 'NH_05_02_05-20210310205811');" target="_self">'기성용 핸드볼→뮬리치 PK골' 성남, 서울 1-0 제압</a></li>
# <li id="newsTxt_li_4"><a href="//news.nate.com
# <li id="newsTxt_li_14"><a href="//news.nate.com/view/20210310n42094?mid=e1100&amp;modit=1615377979" onclick="setTabInfo();ndrclick('MEC67', 'NH_06_02_13-20210310204117');" target="_self">전수경 "싱글맘 된 띠동갑 친구 김현숙 응원…새로운 시작"</a></li>
# </ul>
# <ul class="type_thumb type01 nHide" id="newsImg_ul_2">
# <li id="newsImg3"></li>
# <li id="newsImg4"></li>
# </ul>
# <div class="view_nplus type01" id="newsPlusItem_1"></div>
# <div class="view_nplus type02" id="newsPlusItem_2"></div>
# <div class="view_nplus type03" id="newsPlusItem_3"></div>
# <div class="view_nplus type04" id="newsPlusItem_4"></div>
# <div class="view_nplus type05" id="newsPlusItem_5"></div>
# <div class="view_nplus type06" id="newsPlusItem_6"></div>
# <div class="view_nplus type07" id="newsPlusItem_7"></div>
# <div class="view_nplus type08" id="newsPlusItem_8"></div>
# <div class="view_nplus type09" id="newsPlusItem_9"></div>
# <div class="view_nplus type10" id="newsPlusItem_10"></div>
# <div class="view_nplus type11" id="newsPlusItem_11"></div>
# <div class="view_nplus type12" id="newsPlusItem_12"></div>
# <div class="view_nplus type13" id="newsPlusItem_13"></div>
# <div class="view_nplus type14" id="newsPlusItem_14"></div>
# <div class="view_nplus type15" id="newsPlusItem_15"></div>
# <div class="overlay_plus type01" id="newsPlusLayer" style="display:none">
# <div class="plus_content">
# <iframe frameborder="0" height="470" id="newsIfr" scrolling="no" src="about:blank" title="뉴스플러스 아이프레임" width="304"></iframe>
# <button class="close" onclick="closeNewsPlus();ndrclick('MEC49','');" title="뉴스플러스 레이어 닫기" type="button" value="뉴스플러스 레이어 닫기">뉴스플러스 레이어 닫기</button>
# </div>
# </div>
# </div>
# <div class="bizCnt">
# <div class="isKeyword">
# <h4>실시간 이슈 키워드</h4>
# <ol class="isKeywordList" id="olLiveIssueKeyword">
# <li>
# <span class="num_rank">6</span>
# <a class="ik" href="javascript:newsBox.clickSearchKeyword('방위비 분담금 13.9%');" onmousedown="nc('MEH21')">
# <span class="txt_rank">방위비 분담금 13.9%</span>
# <span class="fc up"><span class="nHide">상승</span>1</span>
# </a>
# </li>
# <li>
# <span class="num_rank">7</span>
# <a class="ik" href="javascript:newsBox.clickSearchKeyword('밥이 되어라');" onmousedown="nc('MEH22')">
# <span class="txt_rank">밥이 되어라</span>
# <span class="fc up"><span class="nHide">상승</span>2</span>
# </a>
# </li>
# <li>
# <span class="num_rank">8</span>
# <a class="ik" href="javascript:newsBox.clickSearchKeyword('생방송 투데이');" onmousedown="nc('MEH23')">
# <span class="txt_rank">생방송 투데이</span>
# <span class="fc same"><span class="nHide">동일</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">9</span>
# <a class="ik" href="javascript:newsBox.clickSearchKeyword('김혜정');" onmousedown="nc('MEH24')">
# <span class="txt_rank">김혜정</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">10</span>
# <a class="ik" href="javascript:newsBox.clickSearchKeyword('최유나');" onmousedown="nc('MEH25')">
# <span class="txt_rank">최유나</span>
# <span class="fc same"><span class="nHide">동일</span></span>
# </a>
# </li>
# </ol>
# <form accept-charset="euc-kr" action="https://news.nate.com/search" id="frmKeyword" name="frmKeyword" onsubmit="return false">
# <input id="bizq" name="q" type="hidden" value=""/>
# </form>
# </div>
# <div class="adBox adbg"><a href="https://cyad1.nate.com/click.kti/nate/main@td_cont_0?ads_no=202839&amp;cmp_no=27516&amp;img_no=339720" target="_blank"> <span class="thumb"><img alt="광고" height="97" lazy="loading" src="https://adimg.nate.com/img/2021/03/child08/child08_0305_168x97.jpg" width="168"/></span> <span class="title" style="height:1.4em; margin-bottom: 0px;">우리나라 아동들을 돕는</span><span class="title" style="height:1.4em; margin-top: 0px;">찬스팔찌와 함께해 주세요</span> </a></div>
# <div class="todayBox" id="divBox"><h3><span class="nHide">서비스 바로가기 링크</span></h3><ul class="svcLink"><li><a href="https://fortune.nate.com/contents/freeunse/freeunseframe.nate?freeUnseId=today03" onmousedown="nc('MEH12');">오늘의 운세</a></li><li><a href="https://stock.nate.com/home/main.do" onmousedown="nc('MEH13');">오늘의 증시</a></li><li><a href="https://estate.nate.com/cp/real/memul.asp?only=345&amp;m_=5&amp;g_=&amp;silk_gnb=&amp;type_m=m" onmousedown="nc('MEH14');">부동산 매물</a></li></ul></div>
# </div>
# <dl class="content_recommend">
# <dt id="dtNewsRecomm"><em>뉴스</em></dt>
# <dd id="newsRecommend">
# <a href="//news.nate.com/recent?mid=n0100" onmousedown="nc('MEF37');setTabInfo();">최신뉴스</a>
# <a href="//news.nate.com/section?mid=n0200" onmousedown="nc('MEF38');setTabInfo();">정치</a>
# <a href="//news.nate.com/section?mid=n0300" onmousedown="nc('MEF39');setTabInfo();">경제</a>
# <a href="//news.nate.com/section?mid=n0400" onmousedown="nc('MEF40');setTabInfo();">사회</a>
# <a href="//news.nate.com/section?mid=n0600" onmousedown="nc('MEF41');setTabInfo();">IT/과학</a>
# </dd>
# </dl>
# <div class="overlay_break" id="breakingNews" style="display: block;"><dl><dt>코로나19 현황</dt><dd><a href="//news.nate.com/view/20210310n10732?modit=1615339180" onclick="setTabInfo();ndrclick('MED43', '');" target="_self">신규확진 470명…총 93,733명 (10일 0시 기준)</a></dd></dl><button class="close" onclick="ndrclick('MED44');newsBox.closeSokboLayer();" title="속보 레이어 닫기" type="button" value="속보 레이어 닫기">속보 레이어 닫기</button></div>
# </div>
# <div class="nav" id="newsOptBtn">
# <span id="newsMoreArea"><em>2</em> / 6</span>
# <button class="pause" id="newsRollingBtn" onclick="newsBox.changeRolling();" title="자동전환기능 정지" type="button" value="자동전환기능 정지">자동전환기능 정지</button>
# <button class="prev" onclick="ndrclick('MEC42');newsBox.showPreNext('P');" title="이전 뉴스 보기" type="button" value="이전 뉴스 보기">이전 뉴스 보기</button>
# <button class="next" onclick="ndrclick('MEC43');newsBox.showPreNext('N');" title="다음 뉴스 보기" type="button" value="다음 뉴스 보기">다음 뉴스 보기</button>
# </div>
# <div id="newsNotice"></div>
# <div class="overlay_ticker" id="ticker_lyr" style="display:none">
# <div class="ticker_content">
# <iframe frameborder="0" height="318" id="ticker_ifm" scrolling="no" src="about:blank" title="티커 아이프레임" width="728"></iframe>
# <button class="close" onclick="nateonTickerClose();" title="티커 닫기" type="button" value="티커 닫기">티커 닫기</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 				//<![CDATA[
# 					loadSpecialBiRolling();
# 				//]]>
# 				</script>
# <!-- tiles:insertAttribute name="NateQ" /-->
# <div class="area_contents" id="divContentsUpper">
# <h3>컨텐츠</h3>
# <div class="menu">
# <h4 class="menu05" id="pannTitle1"><a href="https://pann.nate.com/talk/ranking" onmousedown="nc('PCN01');" title="톡커들의 선택">톡커들의 선택</a></h4>
# <h4 class="menu06" id="pannTitle2"><a href="https://pann.nate.com/today/talk" onmousedown="nc('PCN02');" title="오늘의 톡">오늘의 톡</a></h4>
# <p class="nav">
# <span><a href="https://pann.nate.com" onclick="objContentsInit.ndrCntUpperHomeLink();" onmousedown="nc('PAN96');">판홈</a><i> | </i><em>1</em> / 2</span>
# <button class="prev" onclick="objPannArea.clickButton('P');" onmousedown="nc('PAN98');" title="이전 컨텐츠 보기" type="button" value="이전 컨텐츠 보기">이전 컨텐츠 보기</button>
# <button class="next" onclick="objPannArea.clickButton('N');" onmousedown="nc('PAN99');" title="다음 컨텐츠 보기" type="button" value="다음 컨텐츠 보기">다음 컨텐츠 보기</button>
# </p>
# </div>
# <div class="content type_rank">
# <ol class="list_rank" id="pannList1">
# <li>
# <span class="num_rank top_rank">1</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358362598" onmousedown="nc('PCN11');">넷이서 생일선물 후기입니다.</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (146)
# 		                </em>
# </li>
# <li>
# <span class="num_rank top_rank">2</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358362837" onmousedown="nc('PCN12');">고딩 원래 이리 힘드냐</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (164)
# 		                </em>
# </li>
# <li>
# <span class="num_rank top_rank">3</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358368262" onmousedown="nc('PCN13');">카이x구찌 컬렉션 현재 상황</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (150)
# 		                </em>
# </li>
# <li>
# <span class="num_rank">4</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358359404" onmousedown="nc('PCN14');">그냥 꼬옥 안아주면 되,,</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (151)
# 		                </em>
# </li>
# <li>
# <span class="num_rank">5</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358358485" onmousedown="nc('PCN15');">추가) 부모님이 61년생이면 자식이 보통 몇살인가요?</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (500)
# 		                </em>
# </li>
# <li>
# <span class="num_rank">6</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358365042" onmousedown="nc('PCN16');">조병규 인스타 업뎃함</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (117)
# 		                </em>
# </li>
# <li>
# <span class="num_rank">7</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358363459" onmousedown="nc('PCN17');">[다들 봐줘] 조병규 학폭 폭로계정 새글 올라옴</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (700)
# 		                </em>
# </li>
# <li>
# <span class="num_rank">8</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358354678" onmousedown="nc('PCN18');">김태형 옷입어</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (535)
# 		                </em>
# </li>
# <li>
# <span class="num_rank">9</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358363663" onmousedown="nc('PCN19');">아침부터 남편이랑 대판싸움! 꼭봐주세요</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (179)
# 		                </em>
# </li>
# <li>
# <span class="num_rank">10</span>
# <a class="link_rank" href="https://pann.nate.com/talk/358364195" onmousedown="nc('PCN20');">선크림 조작사건 멘붕오네</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (86)
# 		                </em>
# </li>
# </ol>
# <ol class="list_rank list_today_talk" id="pannList2">
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358329678" onmousedown="nc('PCN21');">하늘 사진 뭐가 제일 예쁜지 골라줘</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (35)
# 		                </em>
# </li>
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358346229" onmousedown="nc('PCN22');">수준 낮고 몰상식한 상사, 이보다 더한 쓰레기는 없다</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (19)
# 		                </em>
# </li>
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358345552" onmousedown="nc('PCN23');">연애도 결혼도 했으면 좋겠지만 통금에 데이트는 하지 말라는 부모님</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (45)
# 		                </em>
# </li>
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358364475" onmousedown="nc('PCN24');">빠른 년생 부심 부리는 친구 대처하는 방법 좀 알려줘</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (51)
# 		                </em>
# </li>
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358342826" onmousedown="nc('PCN25');">이제는 썸에서 연애로 넘어가고 싶은데 너무 어렵다</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (19)
# 		                </em>
# </li>
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358347528" onmousedown="nc('PCN26');">성인인데 본인 전화 요금도 내지 않는 게으른 딸</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (43)
# 		                </em>
# </li>
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358343340" onmousedown="nc('PCN27');">너무 억울한 음식점 노쇼, 사과라도 받고 싶습니다 </a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (63)
# 		                </em>
# </li>
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358363480" onmousedown="nc('PCN28');">앞으로 무슨 일을 해야 할지 막막하고 두렵습니다</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (13)
# 		                </em>
# </li>
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358346163" onmousedown="nc('PCN29');">업무 기한 약속을 지키지 않는 부하 직원을 어쩌면 좋죠</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (12)
# 		                </em>
# </li>
# <li>
# <a class="link_rank" href="https://pann.nate.com/talk/358343553" onmousedown="nc('PCN30');">취직했는데 부모님 용돈을 챙겨드려야 하나요?</a>
# <em class="emph">
# <span class="nHide">댓글</span>
# 		                    (31)
# 		                </em>
# </li>
# </ol>
# <dl class="content_recommend">
# <dt><em>추천 서비스</em></dt>
# <dd><a href="https://pann.nate.com/talk" onmousedown="nc('MRC05');">톡톡</a><a href="https://pann.nate.com/fantalk" onmousedown="nc('MRC06');">팬톡</a><a href="https://pann.nate.com/talk/ImageTheme/index" onmousedown="nc('MRC07');">판포토</a><a href="https://pann.nate.com/talk/c20028" onmousedown="nc('MRC08');">엔터톡</a></dd>
# </dl>
# </div>
# </div>
# <div class="area_issue" id="divIssueUp">
# <h3>키워드</h3>
# <div class="menu">
# <div class="keyword_list">
# <div class="list_top">
# <h4 class="menu08"><a href="javascript:issueContents.clickIssueUpNateTv(0)" onmousedown="nc('CTG08')">TV</a></h4>
# <h4 class="menu01"><a href="javascript:issueContents.clickIssueUpCategory(1, 0)" onmousedown="nc('CTG01');">여행/맛집</a></h4>
# <h4 class="menu02 on"><a href="javascript:issueContents.clickIssueUpCategory(2, 0)" onmousedown="nc('CTG02');">뷰티</a></h4>
# <h4 class="menu03"><a href="javascript:issueContents.clickIssueUpCategory(3, 0)" onmousedown="nc('CTG03');">푸드</a></h4>
# <h4 class="menu04"><a href="javascript:issueContents.clickIssueUpCategory(4, 0)" onmousedown="nc('CTG04');">스타</a></h4>
# <h4 class="menu05"><a href="javascript:issueContents.clickIssueUpCategory(5, 0)" onmousedown="nc('CTG05');">패션</a></h4>
# <h4 class="menu06"><a href="javascript:issueContents.clickIssueUpCategory(6, 0)" onmousedown="nc('CTG06');">라이프</a></h4>
# <h4 class="menu07" id="issueTabShopping"><a href="javascript:issueContents.clickIssueUpShopping()" onmousedown="nc('CTG07');">쇼핑</a></h4>
# </div>
# <div class="list_btm" id="divIssueKeyword">
# <h5 class="on"><a href="javascript:issueContents.clickIssueUpCategory(2, 0)" onmousedown="nc('CCA08');">건성 피부용</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(2, 1)" onmousedown="nc('CCA09');">포인트 메이크업</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(2, 2)" onmousedown="nc('CCA10');">앰풀 효과</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(2, 3)" onmousedown="nc('CCA11');">마스크 팩</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(2, 4)" onmousedown="nc('CCA12');">얼굴 잡티 커버</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(2, 5)" onmousedown="nc('CCA13');">매트 타입</a></h5><h5><a href="javascript:issueContents.clickIssueUpCategory(2, 6)" onmousedown="nc('CCA14');">오일 뷰티</a></h5></div>
# </div>
# </div>
# <div class="content" id="divIssueUpContents">
# <ul><li class="type_thumb"><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '0');" onmousedown="nc5('CAH01','46349','66','1');nc2('CAB01');"><span class="thumb"><img alt="" height="201" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615179598378.jpg" width="169"/><span class="bg_shadow"></span></span><span class="title"><strong>건조하고 가려운</strong><br/><strong>두피에 영양 공급!</strong></span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '1');" onmousedown="nc5('CAH02','46349','66','2');nc2('CAB01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615179572372.jpg" width="169"/></span><span class="title"><strong>'겉보속촉'인 데다</strong><br/><strong>지속력도 좋다는데</strong></span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '2');" onmousedown="nc5('CAH03','46349','66','3');nc2('CAB01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615179619351.jpg" width="169"/></span><span class="title">꾸준하게 써 보니<br/>건조할 틈 없는 듯!</span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '3');" onmousedown="nc5('CAH04','46349','66','4');nc2('CAB01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615179626893.jpg" width="169"/></span><span class="title">촉촉한 피부 표현<br/>도와줄 브러시</span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '4');" onmousedown="nc5('CAH05','46349','66','5');nc2('CAB01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615179590392.jpg" width="169"/></span><span class="title"><strong>씻을 필요 없는</strong><br/><strong>'인생 클렌징 워터'</strong></span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '5');" onmousedown="nc5('CAH06','46349','66','6');nc2('CAB01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615179580158.jpg" width="169"/></span><span class="title"><strong>피부 결은 물론</strong><br/><strong>각질 관리까지?</strong></span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '6');" onmousedown="nc5('CAH07','46349','66','7');nc2('CAB01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615179602399.jpg" width="169"/></span><span class="title">소량으로 충분한<br/>고농축 아이템</span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '7');" onmousedown="nc5('CAH08','46349','66','8');nc2('CAB01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615179594034.jpg" width="169"/></span><span class="title">노화 방지 성분이<br/>함유되어 있다고?</span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '8');" onmousedown="nc5('CAH09','46349','66','9');nc2('CAB01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615179586593.jpg" width="169"/></span><span class="title">흡수가 잘 돼서<br/>보호막 씌운 느낌</span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '9');" onmousedown="nc5('CAH10','46349','66','10');nc2('CAB01');"><span class="thumb"><img alt="" height="126" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615268455666.jpg" width="169"/></span><span class="title">피부 장벽을 위한<br/>저자극 보습 크림</span></a><cite>뷰티 <em>추천콘텐츠</em></cite></li><li><a href="javascript:;" onclick="issueContents.clickDetailInfo('2', '0', '10');" onmousedown="nc5('CAH11','46349','66',' ...
# <div class="content type_err nHide" id="emergencyLayer">
# <h4 class="">쇼핑탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>쇼핑탭은 지금 점검</strong> 중입니다.</p>
# <a href="https://shopping.nate.com/">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="overlay_ally" style="display:none;"></div>
# <div class="movplay" id="movieSec">
# <div class="issuemov">
# <div id="divPlayer"></div>
# <a class="btn_view_detail" href="" id="movieDetailLink" onmousedown="javascript:nc('MVA02');" target="" title="광고 자세히보기">광고 자세히보기</a>
# <button class="btn_x_small_white" onclick="issueContents.closeMovie();" onmousedown="nc('CZA02')" title="동영상 플레이 레이어 닫기" type="button" value="동영상 플레이 레이어 닫기">동영상 플레이 레이어 닫기</button>
# </div>
# <span class="shadow"></span>
# </div>
# </div>
# <div class="area_best">
# <h3>베스트 컨텐츠</h3>
# <h4>당신이 놓친 오늘의<br/>추천 콘텐츠</h4>
# <ul>
# <li>
# <a href="https://news.nate.com/view/20210208n19700" onmousedown="nc('RCM01');" title="창덕궁 성곽을 따라 탐식하고 싶다면">
# <span class="thumb">
# <img alt="창덕궁 성곽을 따라 탐식하고 싶다면" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615186438450.jpg" width="94"/></span>
# <span class="title">
# 						창덕궁 성곽을 따라 탐식하고 싶다면
# 						</span>
# <cite>
# 						 맛집
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://pann.nate.com/talk/357454572" onmousedown="nc('RCM02');" title="요즘에 대중적으로 잘 나가는 소속사?">
# <span class="thumb">
# <img alt="요즘에 대중적으로 잘 나가는 소속사?" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615186590463.jpg" width="94"/></span>
# <span class="title">
# 						요즘에 대중적으로 잘 나가는 소속사?
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://pann.nate.com/talk/357453534" onmousedown="nc('RCM03');" title="'성덕'의 표본이 된 남자 아이돌 보니">
# <span class="thumb">
# <img alt="'성덕'의 표본이 된 남자 아이돌 보니" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615186612904.jpg" width="94"/></span>
# <span class="title">
# 						'성덕'의 표본이 된 남자 아이돌 보니
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://pann.nate.com/talk/357962111" onmousedown="nc('RCM04');" title="한식에 밑반찬까지! 9년 차 요리 실력">
# <span class="thumb">
# <img alt="한식에 밑반찬까지! 9년 차 요리 실력" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615186621721.jpg" width="94"/></span>
# <span class="title">
# 						한식에 밑반찬까지! 9년 차 요리 실력
# 						</span>
# <cite>
# 						 푸드
# 						</cite>
# </a>
# </li>
# </ul>
# </div>
# <div class="area_ranking">
# <h3>랭킹</h3>
# <div class="menu">
# <h4 class="menu04"><div class="tit">Fun&amp;Fun해</div></h4>
# </div>
# <div class="content">
# <ul class="type_thumb">
# <li>
# <a href="https://fortune.nate.com/content/contentInfo.nate?searchcontscd=CT001376" onmousedown="nc('RKN91')" title="운세ㅣ천지인 사주"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615256025549.gif"/></span>
# <span class="title">운세ㅣ천지인 사주<span class="cite">인생은 만들어 나가는 것</span> </span></a>
# </li>
# <li>
# <a href="https://fortune.nate.com/contents/freeunse/freeunseframe.nate?freeUnseId=CT001221" onmousedown="nc('RKN92')" title="운세ㅣ오늘 고백해도 될까"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615256031257.gif"/></span>
# <span class="title">운세ㅣ오늘 고백해도 될까<span class="cite">이성과의 오늘하루</span> </span></a>
# </li>
# <li>
# <a href="http://gs.nate.pupugame.com/" onmousedown="nc('RKN93')" title="군신 | 레벨달성 선물"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615256038616.jpg"/></span>
# <span class="title">군신 | 레벨달성 선물<span class="cite">아무 조건 없이! 아이템 획득!</span> </span></a>
# </li>
# <li>
# <a href="https://comics.nate.com/main/detail.php?btno=76868" onmousedown="nc('RKN94')" title="만화 | 내 비밀을 알아내줘"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615256043741.jpg"/></span>
# <span class="title">만화 | 내 비밀을 알아내줘<span class="cite">유모의 비밀</span> </span></a>
# </li>
# <li>
# <a href="https://comics.nate.com/main/detail.php?btno=73899" onmousedown="nc('RKN95')" title="만화 | 그날 깜빵에서 일어난 일"><span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/cms/content_pool/2021/03/1615256049354.png"/></span>
# <span class="title">만화 | 그날 깜빵에서 일어난 일<span class="cite">지명수배</span> </span></a>
# </li>
# </ul>
# </div>
# </div>
# <hr/>
# <h2>쇼핑&amp; 광고 영역</h2>
# <div class="area_shopping" id="shopping" style="">
# <h3>쇼핑</h3>
# <div class="mall1shop" id="shopitemMall">
# <h3 class="tab" id="mall1Title"><a class="link" href="http://shopping.nate.com" onmousedown="ndrclick2('NFA01')" target="_top">쇼핑홈</a></h3>
# <div class="shopmall" id="mall1Box"><strong class="nHide">몰 리스트</strong><ul class="txtlist"><li class="txt_li"><a href="http://ammonia.daum.net/cptclick?contentseq=1806179&amp;puid=104563234230660368&amp;pagenum=1&amp;impprodnum=0&amp;contentnum=1&amp;positionseq=46135&amp;detailpositionseq=45993" onmousedown="ndrclick2('NFI01')" target="_blank"><b>11번가</b></a></li><li class="txt_li"><a href="http://ammonia.daum.net/cptclick?contentseq=1806175&amp;puid=104563234230660368&amp;pagenum=1&amp;impprodnum=1&amp;contentnum=1&amp;positionseq=46135&amp;detailpositionseq=45993" onmousedown="ndrclick2('NFI02')" target="_blank"><b>G마켓</b></a></li><li class="txt_li"><a href="http://ammonia.daum.net/cptclick?contentseq=1806176&amp;puid=104563234230660368&amp;pagenum=1&amp;impprodnum=2&amp;contentnum=1&amp;positionseq=46135&amp;detailpositionseq=45993" onmousedown="ndrclick2('NFI03')" target="_blank"><b>옥션</b></a></li></ul><ul class="txtlist"><li class="txt_li"><a href="http://ammonia.daum.net/cptclick?contentseq=1810004&amp;puid=104563234230385247&amp;pagenum=1&amp;impprodnum=0&amp;contentnum=1&amp;positionseq=46134&amp;detailpositionseq=45990" onmousedown="ndrclick2('NFI04')" target="_blank">스타일온미 </a></li><li class="txt_li"><a href="http://ammonia.daum.net/cptclick?contentseq=1
>
# <div class="area_quick" id="divQuickMenu">
# <h3>퀵링크</h3>
# <ul>
# <li class="totop"><a href="javascript:;" onmousedown="nc('RAB15');"><span>맨위로</span></a></li>
# <li>
# <a href="http://estate.nate.com/" onmousedown="nc('RAB20');" title="부동산 서비스 가기">부동산</a>
# </li>
# <li>
# <a href="http://stock.nate.com/home/main.do" onmousedown="nc('RAB22');" title="증권 서비스 가기">증권</a>
# </li>
# <li>
# <a href="http://mobile.nate.com/" onmousedown="nc('RAB19');" title="컬러링 서비스 가기">컬러링</a>
# </li>
# <li>
# <a href="http://editor.nate.com/" onmousedown="nc('RAB23');" title="이슈UP추천 서비스 가기">이슈UP추천</a>
# </li>
# <li class="issue"><a href="javascript:;" onmousedown="nc('RAB08');">이슈<em class="issueup">UP</em></a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <h2>푸터 영역</h2>
# <div class="notice">
# <h3><a href="http://helpdesk.nate.com/mainnotice/nate/list.asp" onmousedown="nc('NFT01');">공지사항</a></h3>
# <a href="https://helpdesk.nate.com/mainnotice/nate/view.asp?number_seq=4341&amp;page=1" onmousedown="nc('NFT02');">메일 서비스 수신정지 정책 변경 안내</a>
# </div>
# <dl>
# <dt>네이트 공용 푸터</dt>
# <dd>
# <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT21');">회사소개</a> <span>|</span>
# <a href="http://business.nate.com/" onmousedown="nc('NFT29');">광고문의</a> <span>|</span>
# <a href="/policy/legal.html" onmousedown="nc('NFT24');">서비스 약관</a> <span>|</span>
# <a href="/policy/privacy.html" onmousedown="nc('NFT25');"><strong>개인정보처리방침</strong></a> <span>|</span>
# <a href="/policy/youthpolicy.html" onmousedown="nc('NFT26');">청소년보호정책</a> <span>|</span>
# <a href="http://helpdesk.nate.com/" onmousedown="nc('NFT11');">고객센터</a> <span>|</span>
# <span class="copyright">© <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT41');" target="_blank"><strong><span class="sk">SK</span> Communications.</strong></a></span>
# </dd>
# </dl>
# <a class="view_all" href="/sitemap/index.html" onmousedown="nc('NFT12');">서비스 전체보기</a>
# </div>
# <hr/>
# <div id="adContainer">
# <h2>광고 영역</h2>
# <div class="area_ad01" id="ad_layer1" style="clear: both; float: none; top: 230px; left: 0px; width: 730px; height: 120px; z-index: 3; overflow: hidden; background: none; display: block;"><a href="https://cyad1.nate.com/click.kti/nate/main3@m_Top1?ads_no%3D203124%26cmp_no%3D27567%26img_no%3D340169" onclick="ADStatTraffic('ad.nate.com/nate/main/top/','ad01')" target="_blank"><img alt="광고" src="https://adimg.nate.com/img/2021/02/wv/wv_a_0219_730x120.jpg" style="border-style:none;"/></a></div>
# <div class="area_ad02 nateAd_brand_default ready" id="ad_layer2"><div id="naw_brand_area"><a href="https://cyad1.nate.com/click.kti/nate/www.nate.com@main2_Right1?ads_no%3D203054%26cmp_no%3D27589%26img_no%3D340410" target="_blank"><img alt="광고이미지" src="https://adimg.nate.com/img/2021/02/26/121512/standard.jpg"/><div class="naw_img_border"></div><div id="naw_preCtr"> <div id="naw_preCtr_sign"> <div id="naw_preCtr_signIcon"></div> <div id="naw_preCtr_r1"><span>마우스</span><span>를 올려주세요</span></div> <div id="naw_preCtr_r3"> <span>로딩중</span> <div id="preCtr_r3_bg"></div><div id="preCtr_r3_progress"></div> </div> </div> </div></a></div></div>
# <div class="area_adual">
# <div class="area_ad03">
# </div>
# <div class="area_ad04">
# </div>
# </div>
# <div class="area_ad05 nHide" id="leftAd05Cj">
# <a href="http://talkon.nate.com/service.html" onmousedown="nc('NBI11');" target="_blank"><img alt="게임할땐 토크온!" height="110" src="//main.nateimg.co.kr/img/v6/talkon_55x110.gif" width="55"/></a>
# </div>
# <div class="area_ad06"></div>
# <div class="area_ad09">
# <!-- iframe id="ifrm_ad09" name="ifrm_ad09" frameborder="0" width="728" height="90" scrolling="no" src="about:blank" title="광고"></iframe -->
# </div>
# <div class="area_ad10">
# <a href="http://cymera.com/main/ko" onmousedown="setNcCode('NAA21|NAA22',iSvcSeqC-1);"><img alt=" 싸이메라" height="90" src="//main.nateimg.co.kr/img/cms/content_pool/2020/12/1607663170859.png" width="332"/></a>
# </div>
# <div id="ad_layer3"></div>
# <div id="ad_layer4" style="display:none;"></div>
# </div>
# </div>
# <div id="cbContainer">
# <div class="area_ad08" id="cbLayer" style="display: none">
# <span class="commTxt">한눈에 보는 오늘 <em>NATE</em>와 함께 하루를 시작하세요.</span>
# <a href="javascript:;" id="cbLayerLink" title="NATE를 시작페이지로">NATE를 시작페이지로</a>
# </div>
# </div>
# </div>
# <div class="setting_moblie" id="plus_footer" style="display: none"></div>
# <span id="layerTemp"></span>
# <script src="/js/common/natead_081.js?v=20200206_02" type="text/javascript"></script>
# <script type="text/javascript">
#
# 	if (isiPad) {
# 		document.write('<img src="//stat.nate.com/stat/stat.tiff?cp_url=[www_ndr.nate.com/ipad/]" width="0"  height="0" border="0" alt="" />');
# 	}
#
# </script>
# <script type="text/javascript">
# //<![CDATA[
# try{
#
# 	var contentsUpperTabMenu = ["null", "http://pann.news.nate.com/info", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_gray.gif", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_black.gif" ];
# 	var contentsUpperTopLink = [["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"]];
# 	var contentsUpperSecondPannTitle = ["톡커들의 선택"];
#
# }catch (e) { }
# //]]>
# </script>
# <!--natemain-->
# <script type="text/javascript">//<![CDATA[
#  CFN_type = ''; CFN_id = ''; CFN_cn = ''; CFN_cmn = ''; CFN_link = ''; CFN_link_id = ''; id = (CFN_type == 'N') ? CFN_id : CFN_link_id; cyid = (CFN_type == 'C') ? CFN_id : CFN_link_id; name = CFN_cn; isEmpas = ('' == '1'); refererDomain = ''; CFN_cust_tp_cd = ''; CFN_sex_cd = ''; loginType = ''; isMobile = 'F'; CFN_link_cust_tp_cd = ''; CFN_link_stat_cd = ''; var ndrLoginStatus = (isNateLogin) ? 'login' : ((bLogout) ? 'byebye' : 'logout'); try { divReferer(refererDomain); } catch (e) { } try { if (isNateLogin) fillPersonInfo();} catch (e) { } pageEnd('', '/');//]]>
# </script><div style="display:none;"><img alt=" " border="0" height="0" src="//stat.nate.com/stat/stat.tiff?cp_url=[www_ndr.nate.com/logout/??ndrparam1=n11&amp;ndrparam4=/&amp;ndru3=&amp;ndrl3=&amp;ndrparam7=161537875538166693]&amp;t=1615378756" width="0"/></div><div id="cbContainer"><div class="area_ad08 set_home" id="cbLayer" style="top: -40px;"><a href="https://erms.nate.com/faq/exSelfFAQA.jsp?PageNo=1&amp;nodeId=NODE0000001315&amp;parentNodeId=NODE0000001207&amp;grandParentNodeId=&amp;nodeDepth=4&amp;checkFaq=0&amp;faqId=FAQS0000012878&amp;index=7" target="_self" title="네이트 시작페이지 설정">네이트 시작페이지 설정</a><button class="close" title="닫기" type="button" value="닫기"></button><span class="commTxt">한눈에 보는 오늘 <em>NATE</em>와 함께 하루를 시작하세요.</span></div></div><div class="ads-bundle-area" style="display: none;"></div></body></html>

# %%
issues = soup.findAll('a', {'class': 'ik'})
for issue in issues:
    print(issue.text.split('\n')[1], end = ', ')
    upDown = issue.text.split('\n')[2]
    if upDown[:2] == '상승':
        print('↑' + upDown[2:])
    elif upDown[:2] == '하락':
        print('↓' + upDown[2:])
    elif upDown[:2] == '동일':
        print('-')
    else:
        print(upDown)
# Out:
# 방위비 분담금 13.9%, ↑1
# 밥이 되어라, ↑2
# 생방송 투데이, -
# 김혜정, new
# 최유나, -
