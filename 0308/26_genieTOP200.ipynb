# %%
import warnings
warnings.filterwarnings('ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt
import time

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg=1 => 1 ~ 50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg=2 => 51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg='
for i in range(1, 5):
    # targetSite = url + str(i)
    targetSite = '{}{}'.format(url, i)
    print(targetSite)
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg=4

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg='
header = {"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers = header)
    # print(request)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    
    # 노래 제목은 'class' 속성이 'title ellipsis'인 <a> 태그 내부에 있다.
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))
    
    i = 0
    for title in titles:
        i += 1
        # print(i, title.text.strip())
        # print(i, title.text.split('\n')[-1].strip())
        print(i, title.text.strip().split('\n')[0])
# Out:
# 1 롤린 (Rollin')
# 2 LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 3 Celebrity
# 4 PARANOIA
# 5 좋은 이별이 있을 리가 없잖아 (Feat. 조현아 of 어반자카파)
# 6 Don't Call Me
# 7 Beautiful Beautiful
# 8 밝게 빛나는 별이 되어 비춰줄게
# 9 Dynamite
# 10 내 손을 잡아
# 11 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
# 12 꼬리 (TAIL)
# 13 VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
# 14 밤하늘의 별을 (2020)
# 15 오늘도 난 봄을 기다려
# 16 고백 (바른연애 길잡이 X 허각)
# 17 우린 어쩌다 헤어진 걸까
# 18 이제 나만 믿어요
# 19 사랑하는 당신께
# 20 Lovesick Girls
# 21 잠이 오질 않네요
# 22 취기를 빌려 (취향저격 그녀 X 산들)
# 23 Blueming
# 24 At My Worst
# 25 술 한잔 해요
# 26 에잇 (Prod. & Feat. SUGA of BTS)
# 27 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 28 HERO
# 29 Savage Love (Laxed - Siren Beat) (BTS Remix)
# 30 I'm Not Cool
# 31 오래된 노래
# 32 비로소 너에게 도착했다 (Full Bloom)
# 33 어느 60대 노부부이야기
# 34 그날에 나는 맘이 편했을까
# 35 Life Goes On
# 36 FLYING HIGH WITH U
# 37 바램
# 38 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 39 2002
# 40 METEOR
# 41 이제 나만 믿어요 (Piano by 조영수)
# 42 힘든 건 사랑이 아니다
# 43 모든 날, 모든 순간 (Every day, Every Moment)
# 44 계단말고 엘리베이터
# ...

# %%
# 아티스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg='
header = {"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers = header)
    # print(request)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')

    # 가수 이름은 'class' 속성이 'artist ellipsis'인 <a> 태그 내부에 있다.
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    # print(artists)
    # print(len(artists))
    
    i = 0
    for artist in artists[5:]:
        i += 1
        # print(i, artist.text.strip())
        # print(i, artist.text.split('\n')[0])
        print(i, artist.text.strip().split('\n')[0])
# Out:
# 1 브레이브걸스 (Brave girls)
# 2 양요섭 & 정은지
# 3 아이유 (IU)
# 4 강다니엘
# 5 MC몽
# 6 SHINee (샤이니)
# 7 온앤오프 (ONF)
# 8 송이한
# 9 방탄소년단
# 10 아이유 (IU)
# 11 10CM
# 12 선미
# 13 미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM)
# 14 경서
# 15 케이시 (Kassy)
# 16 허각
# 17 허각
# 18 임영웅
# 19 폴킴
# 20 BLACKPINK
# 21 장범준
# 22 산들
# 23 아이유 (IU)
# 24 Pink Sweat$
# 25 경서 (경서예지) & MJ (써니사이드)
# 26 아이유 (IU)
# 27 장범준
# 28 임영웅
# 29 Jawsh 685 & Jason Derulo & 방탄소년단
# 30 현아
# 31 Standing Egg (스탠딩 에그)
# 32 마크툽 (Maktub)
# 33 임영웅
# 34 이예준
# 35 방탄소년단
# 36 빈첸
# 37 임영웅
# 38 적재
# 39 Anne-Marie
# 40 창모 (CHANGMO)
# 41 임영웅
# 42 임창정
# 43 폴킴
# 44 임영웅
# 45 방탄소년단
# 46 이수 (엠씨더맥스)
# 47 임영웅
# 48 에픽하이 (EPIK HIGH)
# 49 청하 & Christopher
# 50 규현 (KYUHYUN)

# %%
# 크롤링한 데이터를 리스트에 저장한다.
genie = []
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210308&hh=20&rtm=Y&pg='
header = {"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers = header)
    time.sleep(1)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    
    # genie 리스트에 노래 제목과 가수 이름을 튜플로 만들어 저장한다.
    for j in range(50):
        genie.append(
            (titles[j].text.strip().split('\n')[0], artists[j + 5].text.strip().split('\n')[0])
        )
print(len(genie))
print(genie)
# Out:
# 200
# ...

# %%
print(dt.now())
for i in range(200):
    print('{0:3d}위 {1} - {2}'.format(i + 1, genie[i][1], genie[i][0]))
# Out:
# 2021-03-08 21:47:27.231092
#   1위 브레이브걸스 (Brave girls) - 롤린 (Rollin')
#   2위 양요섭 & 정은지 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
#   3위 아이유 (IU) - Celebrity
#   4위 강다니엘 - PARANOIA
#   5위 MC몽 - 좋은 이별이 있을 리가 없잖아 (Feat. 조현아 of 어반자카파)
#   6위 SHINee (샤이니) - Don't Call Me
#   7위 온앤오프 (ONF) - Beautiful Beautiful
#   8위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
#   9위 방탄소년단 - Dynamite
#  10위 아이유 (IU) - 내 손을 잡아
#  11위 10CM - 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
#  12위 선미 - 꼬리 (TAIL)
#  13위 미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
#  14위 경서 - 밤하늘의 별을 (2020)
#  15위 케이시 (Kassy) - 오늘도 난 봄을 기다려
#  16위 허각 - 고백 (바른연애 길잡이 X 허각)
#  17위 허각 - 우린 어쩌다 헤어진 걸까
#  18위 임영웅 - 이제 나만 믿어요
#  19위 폴킴 - 사랑하는 당신께
#  20위 BLACKPINK - Lovesick Girls
#  21위 장범준 - 잠이 오질 않네요
#  22위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  23위 아이유 (IU) - Blueming
#  24위 Pink Sweat$ - At My Worst
#  25위 경서 (경서예지) & MJ (써니사이드) - 술 한잔 해요
#  26위 아이유 (IU) - 에잇 (Prod. & Feat. SUGA of BTS)
# ...

# %%
# 크롤링한 결과를 텍스트 파일에 저장한다.
file = open('genieTOP200.txt', 'w')
file.write('{} 현재 Genie 뮤직 실시간 TOP 200\n'.format(dt.now()))
for i in range(200):
    data = '{0:3d}위 {1} - {2}'.format(i + 1, genie[i][1], genie[i][0])
    file.write(data + '\n')
file.close()
print('genieTOP200.txt 파일에 쓰기 완료')
# Out:
# genieTOP200.txt 파일에 쓰기 완료

# %%
# 텍스트 파일에 저장된 데이터를 읽어서 출력한다.
try:
    file = open('genieTOP200.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
except FileNotFoundError:
    print('genieTOP200.txt 파일이 디스크에 없습니다.')
